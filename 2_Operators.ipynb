# %% [markdown]
# <a href="https://colab.research.google.com/github/SanikaRanpise/Python-Basics/blob/main/2_Operators.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Arithmetic Operators

# %%
num1 = 3
num2 = 5
print(num1 , num2)
print(type(num1), type(num2))
# Out:
# 3 5
# <class 'int'> <class 'int'>

# %%
print(num1 + num2)
print(num1 - num2)
print(num1 * num2)
print(num1 / num2)
# Out:
# 8
# -2
# 15
# 0.6

# %%
print(num1 // num2)
print(num1 % num2)
print(num1 ** num2)
# Out:
# 0
# 3
# 243

# %%
print(9 // 3)
print(8 // 3)
print(7 // 3)
print(6 // 3)
# Out:
# 3
# 2
# 2
# 2

# %%
print(9 % 3)
print(8 % 3)
print(7 % 3)
print(6 % 3)
# Out:
# 0
# 2
# 1
# 0

# %%
print(5 * 4 + 1)
print(1 + 5 * 4)
print(5 * (4 + 1))
# Out:
# 21
# 21
# 25

# %% [markdown]
# Comparison Operator

# %%
print(2 == 1)
print(2 == 2)
# Out:
# False
# True

# %%
print(3 != 2)
print(3 > 2)
print(3 < 2)
print(3 >= 2)
print(3 <= 2)
# Out:
# True
# True
# False
# True
# False

# %% [markdown]
# Assignment Operator

# %%
num = 4
print(num)

num += 1
print(num)
# Out:
# 4
# 5

# %%
num = 4
print(num)

num -= 1
print(num)
# Out:
# 4
# 3

# %%
num = 4
print(num)

num *= 2
print(num)
# Out:
# 4
# 8

# %%
num = 4
print(num)

num /= 2
print(num)
# Out:
# 4
# 2.0

# %% [markdown]
# Logical Operators

# %%
print(True and True)
print(True and False)
print(False and True)
print(False & False)
# Out:
# True
# False
# False
# False

# %%
print(True or True)
print(True or False)
print(False | True)
print(False | False)
# Out:
# True
# True
# True
# False

# %%
print(not True)
print(not False)
# Out:
# False
# True

# %% [markdown]
# Logical Operations

# %%
x = 5
print(x > 4 and x < 6)
# Out:
# True

# %%
x = 5
print(x > 3 or x < 4)
# Out:
# True

# %%
x = 5
print(not(x > 3 and x < 10))
# Out:
# False

# %%
# abs() function gives positive number

print(abs(-2))
print(abs(-2.1))
# Out:
# 2
# 2.1

# %%
# round() function rounds off the digits after decimal point

print(round(3.45))
print(round(-3.95))
# Out:
# 3
# -4

# %%
# round() function with precision

print(round(3.46, 1))   # round the number till 1 decimal place
print(round(3.46, 2))   # round the number till 2 decimal place

print(round(3.469, 1))   # round the number till 1 decimal place
print(round(3.469, 2))   # round the number till 2 decimal place
# Out:
# 3.5
# 3.46
# 3.5
# 3.47

# %%
# Just like integer, arithmatic operations can be applied on float

new1 = 2.1
new2 = 0.3

print(new1 + new2)
print(new1 - new2)
# Out:
# 2.4
# 1.8

# %%
# Float and integer can be added to each other

fir = 3  # int
sec = 0.1  # float
print (fir + sec)
# Out:
# 3.1

# %%
# Funnily, if you add string and integer, you'll get a string

num1 = 'Hello'
num2 = '5'
print(num1 + num2)   # this is simply concatenation of strings
# Python is smart to figure out that one of the variable is string so the output results in string
# Out:
# Hello5

# %%
# Type casting  i.e. converting string to int

a = '2'
b = '3'
print(a, type(a))
print(b, type(b))
print('Addition = ', a+b)   # because this is string + string, the output will be simple concatenation of the digits i.e. output will be 23 instead of 5

print()                     # Leaves a blank space in output

a = int(a)
b = int(b)
print(a, type(a))       # here you'll get output as int
print(b, type(b))       # here you'll get output as int
print('Addition = ', a+b)
# Out:
# 2 <class 'str'>
# 3 <class 'str'>
# Addition =  23
#
# 2 <class 'int'>
# 3 <class 'int'>
# Addition =  5

# %%
# But if you go about typecasting a proper string into int it'll give error
# THIS CELL WILL GIVE ERROR. IT IS MEANT FOR THAT. DON'T WORRY BECAUSE IT IS RED

a = 'hi'
a = int(a)    # this line will throw error (because python cannot convert 'hi' into  integer)
print(a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_5547/4205277549.py in <cell line: 0>()
#       3
#       4 a = 'hi'
# ----> 5 a = int(a)    # this line will throw error (because python cannot convert 'hi' into  integer)
#       6 print(a)
#
# ValueError: invalid literal for int() with base 10: 'hi'

# %%
# Float to str

num = 2.0
print(type(num))
num = str(num)
print(type(num))
# Out:
# <class 'float'>
# <class 'str'>

# %%
# str to bool

num = 'True'
print(type(num))
num = bool(num)
print(type(num))
# Out:
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# Typecasting with input()

# %%
# Note, anything that you write in input() is accepted as string, even if it is an integer. Try passing some integer as input and check its datatype.

num = input('enter some integer  -  ')   # pass some number e.g. 2
print(num)
print(type(num))
# Out:
# enter some integer  -  2
# 2
# <class 'str'>

# %%
# To convert string into integer which is passed in input(), you can simply wrap it up in int() or float() class

num = input('Enter some number --- ')     # pass some number e.g. 2
print(num, type(num))
new = int(num)            # this is called typecasting (i.e. you are changing data type of variable) (this line will give you error if you pass some text in the input box, try it!)
print(new, type(new))
# Out:
# Enter some number --- 2
# 2 <class 'str'>
# 2 <class 'int'>

# %%
# Carry addition of two user-inputted numbers

num1 = input('Enter first number:  ')
num2 = input('Enter second number:  ')
print(num1 + num2)    # this will simply append the two numbers one after the other
print(int(num1) + int(num2))   # this will actuall carry out the addition
# Out:
# Enter first number:  12
# Enter second number:  23
# 1223
# 35

# %% [markdown]
# If Else based on comparison operators

# %% [markdown]
# Simple If-else
# if is a special keyword in python used to denote condition.
#
# Condition requires any of the logical operators we saw above.

# %%
x = 4
y = 3
if x > y:             # if is followed by condition which is followed by :    # That's standard syntax
  print('yes, x is indeed greater than y')     # the main codeblock of if clause is denoted by leaving 4 indents (if there are less or more than 4 indents, it'll throw error)
# Out:
# yes, x is indeed greater than y

# %%
x = 14
y = 15
if x > y:             # if is followed by condition which is followed by :    # That's standard syntax
  print('yes, x is indeed greater than y')
print('this statement is not part of if clause, hence there is no indent here')
# Out:
# this statement is not part of if clause, hence there is no indent here

# %%
x = 14
y = 13
if x > y:             # if is followed by condition which is followed by :    # That's standard syntax
  print('yes, x is indeed greater than y')
  print('I want to be part of if clause as well, so i have given 4 indents before print()')
print('this statement is not part of if clause, hence there is no indent here')
# Out:
# yes, x is indeed greater than y
# I want to be part of if clause as well, so i have given 4 indents before print()
# this statement is not part of if clause, hence there is no indent here

# %%
# else statement lies on the same level as if
if 4 > 5:
    print('four is greater than five')
else:
    print('four is smaller than five')
# Out:
# four is smaller than five

# %% [markdown]
# Extra if-else programs for practice

# %%
# multiple if else => use elif

height = 176
if height < 140:
    print('too short')
elif height < 180:
    print('height is ok')
else:
    print('too tall')
# Out:
# height is ok

# %%
# You can pass boolean value (True or False) to the condition in if. In that case, you don't need any logical operator like == or !=


is_subscribed = False
if is_subscribed:              # Read it like - if True do THIS else do THAT
    print('Thank you for the subscription!')
else:
    print('Please subscribe')
# Out:
# Please subscribe

# %%
is_subscribed = True
if is_subscribed:
    print('Thank you for the subscription!')
else:
    print('Please subscribe')
# Out:
# Thank you for the subscription!

# %%
x = 3
y = 4

if x < y and x + y > 5:
    print('both statements are true')

if x < y or x > y:
    print('one of the statement is true')

if x < y and not x + y < 5:
    print('both the statements must be true')
# Out:
# both statements are true
# one of the statement is true
# both the statements must be true

# %%
# Nested If

x = 7
if x > 10:
    print('x is greater than 10')
    if x > 20:
        print('x is greater than 20')
        if x > 30:
            print('x is greater than 30')
        else:
            print('x is smaller than 30')
    else:
        print('x is smaller than 20')
else:
    print('x is smaller than 10')
# Out:
# x is smaller than 10

# %%
# To find out if inputted number is within the range of 3 to 10
# if both conditions are True only then answer will be True else false

x = int(input("Enter any number within range 10: "))     # if you pass anything other than integer, it'll throw error. Because we are typecasting here itself
print(x >= 3 and x <= 10)
# Out:
# Enter any number within range 10: 5
# True
