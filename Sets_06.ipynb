# %% [markdown]
# <a href="https://colab.research.google.com/github/SanikaRanpise/Python-Basics/blob/main/Sets_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Sets

# %%
thisset = {"apple", "banana", "cherry"}
print(thisset)

# %%
my_set = {1,2,3}
print(my_set)

# %%
print(type(my_set))

# %%
my_set1 = {1,"Hello",3.5}
my_set1
# Out:
# {1, 3.5, 'Hello'}

# %%
type(my_set1)
# Out:
# set

# %%
empty_set = set()
empty_set
# Out:
# set()

# %%
print(type(empty_set))
# Out:
# <class 'set'>

# %%
type(empty_set)
# Out:
# set

# %%
my_set2 = {1,2,3,4,5,5,5,6,7,8}
my_set2
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
print(len(my_set2))
# Out:
# 8

# %%
my_set = set()
my_set
# Out:
# set()

# %%
my_set.add(1)
my_set
# Out:
# {1}

# %%
my_set.update([5,7,8,12])
print(my_set)
# Out:
# {1, 5, 7, 8, 12}

# %%
my_set.update([5,7,8,12],[90,100,75])
my_set
# Out:
# {1, 5, 7, 8, 12, 75, 90, 100}

# %%
my_set = {1,2,3}
print(my_set)
# Out:
# {1, 2, 3}

# %%
print(type(my_set))
# Out:
# <class 'set'>

# %%
my_set1 = {1,"Hello",3.5}
my_set1
# Out:
# {1, 3.5, 'Hello'}

# %%
type(my_set1)
# Out:
# set

# %%
empty_set = set()
print(empty_set)
# Out:
# set()

# %%
print(type(empty_set))
# Out:
# <class 'set'>

# %%
type(empty_set)
# Out:
# set

# %%
empty_set = {}
print(empty_set)
# Out:
# {}

# %%
print(type(empty_set))
# Out:
# <class 'dict'>

# %%
my_set2 = {1,2,3,5,5,5,6,7,8,9}
my_set2
# Out:
# {1, 2, 3, 5, 6, 7, 8, 9}

# %%
print(len(my_set2))
# Out:
# 8

# %%
my_set=set()
my_set
# Out:
# set()

# %%
my_set.add(3)

# %%
my_set
# Out:
# {3}

# %%
my_set.add(5)
my_set
# Out:
# {3, 5}

# %%
my_set.update([5,7,8,12])
my_set
# Out:
# {3, 5, 7, 8, 12}

# %%
my_set.update([5,99,15],{90,100,75})
my_set
# Out:
# {3, 5, 7, 8, 12, 15, 75, 90, 99, 100}

# %%
sorted(my_set)
# Out:
# [3, 5, 7, 8, 12, 15, 75, 90, 99, 100]

# %%
set_as_list=list(my_set)
print(set_as_list)
# Out:
# [3, 99, 5, 100, 7, 8, 75, 12, 15, 90]

# %%
my_set.discard(8)
my_set
# Out:
# {3, 5, 7, 12, 15, 75, 90, 99, 100}

# %%
my_set.discard(100)
my_set
# Out:
# {3, 5, 7, 12, 15, 75, 90, 99}

# %%
my_set.discard(1000)
my_set
# Out:
# {3, 5, 7, 12, 15, 75, 90, 99}

# %%
my_set.remove(75)
my_set
# Out:
# {3, 5, 7, 12, 15, 90, 99}
